# %%
import pandas as pd
import numpy as np
import os

# %%
from datetime import datetime
from collections import defaultdict

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# joint_df = pd.read_csv('./joint_clean_data/joint.csv', index_col=0)
# Out:
# c:\users\vpoletae\appdata\local\continuum\anaconda3\envs\mytfenv\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (29,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# goal_domain = joint_df[['goal_domain']]

# %%
# goal_domain.to_csv('goal_domains.csv')

# %%
goal_domain = pd.read_csv('goal_domains.csv', index_col=0)

# %%
goal_domain.dropna(inplace=True)

# %%
goal_domain.head()
# Out:
#                                          goal_domain
# 0  Творчество и создание нового (Изобразительное ...
# 1  Универсальные компетенции, гибкие навыки (soft...
# 2  Иностранные языки, гуманитарные знания и навык...
# 3  Прикладные знания и навыки, ручной труд (инфор...
# 4  Универсальные компетенции, гибкие навыки (soft...

# %%
cv = CountVectorizer(max_df=0.5)
dtm = cv.fit_transform(goal_domain['goal_domain'])

# %%
LDA = LatentDirichletAllocation(n_components=11,
                               batch_size=256,
                               learning_decay=0.2) #playaround # 11 because we have 11 labels

# %%
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(batch_size=256, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.2,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=11, n_jobs=None,
#                           perp_tol=0.1, random_state=None,
#                           topic_word_prior=None, total_samples=1000000.0,
#                           verbose=0)

# %%
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names()[i] for i in topic.argsort()[-10:]]) #adjust
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['обучение', 'что', 'это', 'сфере', 'области', 'все', 'экономика', 'деятельность', 'технологии', 'образование']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['прочие', 'цифровые', 'данными', 'работа', 'компьютерных', 'освоение', 'программ', 'программирование', 'it', 'математика']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['коучинг', 'освоение', 'педагогических', 'методик', 'навыков', 'психология', 'знания', 'гуманитарные', 'иностранные', 'языки']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['деятельности', 'проектов', 'технологий', 'разработка', 'жизни', 'управление', 'развитие', 'для', 'новых', 'на']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['менеджмент', 'рабочих', 'процессов', 'организация', 'нормативное', 'регулирование', 'работа', 'финансы', 'бизнес', 'личные']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['сочинительство', 'ручное', 'рукоделие', 'изобразительное', 'декор', 'изобретательство', 'искусство', 'нового', 'творчество', 'создание']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['планирование', 'менеджмент', 'осознанность', 'мышления', 'развитие', 'гибкие', 'универсальные', 'soft', 'skills', 'компетенции']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['технические', 'астрономия', 'медицина', 'земле', 'экология', 'физика', 'химия', 'биология', 'естественные', 'науки']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['веса', 'правильное', 'питание', 'контроль', 'привычки', 'полезные', 'самочувствие', 'спорт', 'внешность', 'зож']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['музыка', 'книг', 'чтение', 'профессиональная', 'не', 'литература', 'знания', 'языки', 'иностранные', 'гуманитарные']
#
#
# THE TOP 15 WORDS FOR TOPIC #10
# ['вождение', 'работа', 'по', 'строительство', 'ручного', 'труда', 'ручной', 'труд', 'прикладные', 'знания']

# %%
topics_tesaurus = {
    'label_attractor_knowledge':['знан', ],
    'label_attractor_hard_skill':['матем'], 
    'label_attractor_soft_skill':['soft'],
    'label_attractor_tool':[],
    'label_attractor_community':['обществ', 'семья'],
    'label_attractor_subjectivity':[],
    'label_attractor_habits':[],
    'label_attractor_career':['карьер', 'менеджм', 'управлен'],
    'label_attractor_fixing':[],
    'label_attractor_art':['худож', 'искусств', 'фотогр'],
    'label_attractor_health':['здоров'],
 
}

# %%
def add_cluster(x):
    group = []
    for key, values in topics_tesaurus.items():
        for val in values:
            if val in x:
                group.append(key)
    return group

# %%
goal_domain['goal_domain'] = goal_domain['goal_domain'].apply(lambda x: x.lower())

# %%
goal_domain['topic'] = goal_domain['goal_domain'].apply(lambda x: add_cluster(x))

# %%
goal_domain['topic_counter'] = goal_domain['topic'].apply(lambda x: len(x))

# %%
goal_domain.head(20) #playaround head-tail, number
# Out:
#                                           goal_domain  \
# 0   творчество и создание нового (изобразительное ...
# 1   универсальные компетенции, гибкие навыки (soft...
# 2   иностранные языки, гуманитарные знания и навык...
# 3   прикладные знания и навыки, ручной труд (инфор...
# 4   универсальные компетенции, гибкие навыки (soft...
# 5   универсальные компетенции, гибкие навыки (soft...
# 6   иностранные языки, гуманитарные знания и навык...
# 7   личные финансы, работа, бизнес и нормативное р...
# 8   личные финансы, работа, бизнес и нормативное р...
# 9   творчество и создание нового (фотография)униве...
# 10  математика и it (работа с данными, программиро...
# 11  личные финансы, работа, бизнес и нормативное р...
# 12  математика и it (работа с данными)математика и...
# 13  личные финансы, работа, бизнес и нормативное р...
# 14                                     юриспруденция
# 15  личные финансы, работа, бизнес и нормативное р...
# 16  личные финансы, работа, бизнес и нормативное р...
# 17                           психология и педагогика
# 18  спорт, зож, внешность и самочувствие (выздоров...
# 19  универсальные компетенции, гибкие навыки (soft...
#
#                                                 topic  topic_counter
# 0                               [label_attractor_art]              1
# 1   [label_attractor_knowledge, label_attractor_so...              5
# 2                         [label_attractor_knowledge]              1
# 3                         [label_attractor_knowledge]              1
# 4   [label_attractor_soft_skill, label_attractor_c...              2
# 5   [label_attractor_knowledge, label_attractor_so...              4
# 6                         [label_attractor_knowledge]              1
# 7                            [label_attractor_career]              1
# 8   [label_attractor_knowledge, label_attractor_so...              3
# 9   [label_attractor_soft_skill, label_attractor_c...              5
# 10                       [label_attractor_hard_skill]              1
# 11                                                 []              0
# 12                       [label_attractor_hard_skill]              1
# 13                           [label_attractor_career]              1
# 14                                                 []              0
# 15  [label_attractor_soft_skill, label_attractor_c...              2
# 16                           [label_attractor_career]              1
# 17                                                 []              0
# 18                           [label_attractor_health]              1
# 19  [label_attractor_soft_skill, label_attractor_c...              2

# %%
goal_domain[goal_domain['topic_counter'] == 0].shape
# Out:
# (4052, 3)

# %%
goal_domain[goal_domain['topic_counter'] == 0].head(50)
# Out:
#                                            goal_domain topic  topic_counter
# 11   личные финансы, работа, бизнес и нормативное р...    []              0
# 14                                      юриспруденция     []              0
# 17                            психология и педагогика     []              0
# 22   психология творчество и создание нового (новые...    []              0
# 24                     естественные науки (психология)    []              0
# 26                         естественные науки (физика)    []              0
# 34   личные финансы, работа, бизнес и нормативное р...    []              0
# 38   личные финансы, работа, бизнес и нормативное р...    []              0
# 49                                         энергетика     []              0
# 54   материальное благополучие и есть материальное ...    []              0
# 55        естественные науки (науки о земле, экология)    []              0
# 56   личные финансы, работа, бизнес и нормативное р...    []              0
# 69   спорт, зож, внешность и самочувствие (зож, пол...    []              0
# 74                  естественные науки (химия, физика)    []              0
# 75                    финансы, информационные системы     []              0
# 79                творчество и создание нового (общее)    []              0
# 81   естественные науки (прикладная информатика в э...    []              0
# 83   личные финансы, работа, бизнес и нормативное р...    []              0
# 97   естественные науки (биология, химия, физика, а...    []              0
# 99   спорт, зож, внешность и самочувствие (йога, ме...    []              0
# 107    творчество и создание нового (изобретательство)    []              0
# 113  личные финансы, работа, бизнес и нормативное р...    []              0
# 114  личные финансы, работа, бизнес и нормативное р...    []              0
# 116  личные финансы, работа, бизнес и нормативное р...    []              0
# 117                                        психология     []              0
# 118                                             мечты     []              0
# 129  личные финансы, работа, бизнес и нормативное р...    []              0
# 130  эта цель относится к различным областям и их с...    []              0
# 134  творчество и создание нового (литературное соч...    []              0
# 150                                 администрирование     []              0
# 152                                          нефтяной     []              0
# 160  личные финансы, работа, бизнес и нормативное р...    []              0
# 165  творчество и создание нового (предпринимательс...    []              0
# 173                              муниципальные услуги     []              0
# 175  спорт, зож, внешность и самочувствие (внешност...    []              0
# 176  спорт, зож, внешность и самочувствие (время)вр...    []              0
# 178  творчество и создание нового (изобретательство...    []              0
# 182  личные финансы, работа, бизнес и нормативное р...    []              0
# 189  это не относится к какой-либо отросли, этот от...    []              0
# 193         промышленная и экологическая безопасность     []              0
# 196  личные финансы, работа, бизнес и нормативное р...    []              0
# 197                               сфера жкх сфера жкх     []              0
# 198  личные финансы, работа, бизнес и нормативное р...    []              0
# 205  личные финансы, работа, бизнес и нормативное р...    []              0
# 220  спорт, зож, внешность и самочувствие (правильн...    []              0
# 222  спорт, зож, внешность и самочувствие (зож, пол...    []              0
# 226   творчество и создание нового (нефтегазовое дело)    []              0
# 251            обеспечение экологической безопасности     []              0
# 253  общее направление цели как я уже писал, ко мно...    []              0
# 254  личные финансы, работа, бизнес и нормативное р...    []              0

# %%
import pickle

# %%
with open('topics_tesaurus.pickle', 'wb') as f:
    pickle.dump(topics_tesaurus, f)
